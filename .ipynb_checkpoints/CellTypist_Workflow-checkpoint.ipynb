# %%
import scanpy as sc
import pandas as pd
import scipy.io as scipy
import celltypist
from celltypist import models
import anndata
import matplotlib.pyplot as plt

# %%
matrix = scipy.mmread('/Users/gagled01/morganLab/Waldenstroms/singlecell/textfiles_csvs/scRNA_SCTransformIntegrated_sparseMatrix.mtx')
gene_list = pd.read_table('/Users/gagled01/morganLab/Waldenstroms/singlecell/textfiles_csvs/scRNA_SCTransformIntegrated_geneNames.txt', header = None)
cell_list = pd.read_table('/Users/gagled01/morganLab/Waldenstroms/singlecell/textfiles_csvs/scRNA_SCTransformIntegrated_cellNames.txt', header = None)

# %%
models.download_models(force_update = True)
model = models.Model.load(model = 'Immune_All_Low.pkl') # low hierarchy = high resolution
# Out:
# 📜 Retrieving model list from server https://celltypist.cog.sanger.ac.uk/models/models.json
# 📚 Total models in list: 18
# 📂 Storing models in /Users/gagled01/.celltypist/data/models
# 💾 Downloading model [1/18]: Immune_All_Low.pkl
# 💾 Downloading model [2/18]: Immune_All_High.pkl
# 💾 Downloading model [3/18]: Adult_Mouse_Gut.pkl
# 💾 Downloading model [4/18]: Autopsy_COVID19_Lung.pkl
# 💾 Downloading model [5/18]: COVID19_Immune_Landscape.pkl
# 💾 Downloading model [6/18]: Cells_Fetal_Lung.pkl
# 💾 Downloading model [7/18]: Cells_Intestinal_Tract.pkl
# 💾 Downloading model [8/18]: Cells_Lung_Airway.pkl
# 💾 Downloading model [9/18]: Developing_Human_Brain.pkl
# 💾 Downloading model [10/18]: Developing_Human_Thymus.pkl
# 💾 Downloading model [11/18]: Developing_Mouse_Brain.pkl
# 💾 Downloading model [12/18]: Healthy_COVID19_PBMC.pkl
# 💾 Downloading model [13/18]: Human_IPF_Lung.pkl
# 💾 Downloading model [14/18]: Human_Lung_Atlas.pkl
# 💾 Downloading model [15/18]: Human_PF_Lung.pkl
# 💾 Downloading model [16/18]: Lethal_COVID19_Lung.pkl
# 💾 Downloading model [17/18]: Nuclei_Lung_Airway.pkl
# 💾 Downloading model [18/18]: Pan_Fetal_Human.pkl

# %%
# need to put absolute path in here apparently...bugs out if i use variable to path, despite the tutorial using a variable
# also need gene and cell files for this

# important to transpose so that the files match up
matrix = matrix.T 
predictions = celltypist.annotate(filename = '/Users/gagled01/morganLab/Waldenstroms/singlecell/WM_PrelimRNA_sparseMatrix.mtx',
                                  gene_file = '/Users/gagled01/morganLab/Waldenstroms/singlecell/WM_PrelimRNA_geneNames.txt',
                                  cell_file = '/Users/gagled01/morganLab/Waldenstroms/singlecell/WM_PrelimRNA_cellNames.txt',
                                  model = 'Immune_All_Low.pkl', majority_voting = True, transpose_input = True)
# Out:
# 📁 Input file is '/Users/gagled01/morganLab/Waldenstroms/singlecell/WM_PrelimRNA_sparseMatrix.mtx'
# ⏳ Loading data
# ⚠️ Warning: the input file seems not a raw count matrix. The prediction result may be biased
# 🔬 Input data has 48567 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 6146 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# OMP: Info #271: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# ⛓️ Over-clustering input data with resolution set to 20
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!

# %%
predictions.predicted_labels
adata = predictions.to_adata()
adata.obs
# Out:
#                      predicted_labels over_clustering majority_voting  \
# AAACAGCCACGTGCTG-1_1   Memory B cells              68  Memory B cells
# AAACAGCCAGGATGGC-1_1   Memory B cells              18  Memory B cells
# AAACAGCCAGGCTAAG-1_1   Memory B cells              11  Memory B cells
# AAACAGCCAGGCTAGA-1_1   Memory B cells              18  Memory B cells
# AAACATGCAGTTTCTC-1_1   Memory B cells              18  Memory B cells
# ...                               ...             ...             ...
# TTTGTTGGTAACTACG-1_7   Memory B cells              27  Memory B cells
# TTTGTTGGTGATCAGC-1_7   Memory B cells             157  Memory B cells
# TTTGTTGGTGCGCAAT-1_7   Memory B cells             258  Memory B cells
# TTTGTTGGTTACAAAC-1_7   Memory B cells             350  Memory B cells
# TTTGTTGGTTAGGCGT-1_7   Memory B cells             133  Memory B cells
#
#                       conf_score
# AAACAGCCACGTGCTG-1_1    0.649371
# AAACAGCCAGGATGGC-1_1    0.574760
# AAACAGCCAGGCTAAG-1_1    0.912066
# AAACAGCCAGGCTAGA-1_1    0.998102
# AAACATGCAGTTTCTC-1_1    0.942622
# ...                          ...
# TTTGTTGGTAACTACG-1_7    0.922817
# TTTGTTGGTGATCAGC-1_7    0.932555
# TTTGTTGGTGCGCAAT-1_7    0.792984
# TTTGTTGGTTACAAAC-1_7    0.999932
# TTTGTTGGTTAGGCGT-1_7    0.897772
#
# [48567 rows x 4 columns]

# %%
sc.tl.umap(adata)
sc.pl.umap(adata, color = ['majority_voting'], legend_loc = 'right margin')
#fig.set_canvas(plt.gcf().canvas)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/06/cw_8lhcn6z12pg5kdt966ps00slj92/T/ipykernel_27483/2393333667.py in <module>
#       1 sc.tl.umap(adata)
#       2 sc.pl.umap(adata, color = ['majority_voting'], legend_loc = 'right margin')
# ----> 3 sc.pl.umap(adata, color = ['patient'], legend_loc = 'right margin')
#       4
#       5 #fig.set_canvas(plt.gcf().canvas)
#
# /opt/anaconda3/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py in umap(adata, **kwargs)
#     667     tl.umap
#     668     """
# --> 669     return embedding(adata, 'umap', **kwargs)
#     670
#     671
#
# /opt/anaconda3/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py in embedding(adata, basis, color, gene_symbols, use_raw, sort_order, edges, edges_width, edges_color, neighbors_key, arrows, arrows_kwds, groups, components, dimensions, layer, projection, scale_factor, color_map, cmap, palette, na_color, na_in_legend, size, frameon, legend_fontsize, legend_fontweight, legend_loc, legend_fontoutline, colorbar_loc, vmax, vmin, vcenter, norm, add_outline, outline_width, outline_color, ncols, hspace, wspace, title, show, save, ax, return_fig, **kwargs)
#     255     # ]
#     256     for count, (value_to_plot, dims) in enumerate(zip(color, dimensions)):
# --> 257         color_source_vector = _get_color_source_vector(
#     258             adata,
#     259             value_to_plot,
#
# /opt/anaconda3/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py in _get_color_source_vector(adata, value_to_plot, use_raw, gene_symbols, layer, groups)
#    1167         values = adata.raw.obs_vector(value_to_plot)
#    1168     else:
# -> 1169         values = adata.obs_vector(value_to_plot, layer=layer)
#    1170     if groups and is_categorical_dtype(values):
#    1171         values = values.replace(values.categories.difference(groups), np.nan)
#
# /opt/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py in obs_vector(self, k, layer)
#    1362                 )
#    1363                 layer = None
# -> 1364         return get_vector(self, k, "obs", "var", layer=layer)
#    1365
#    1366     def var_vector(self, k, *, layer: Optional[str] = None) -> np.ndarray:
#
# /opt/anaconda3/lib/python3.9/site-packages/anndata/_core/index.py in get_vector(adata, k, coldim, idxdim, layer)
#     160         )
#     161     elif (in_col + in_idx) == 0:
# --> 162         raise KeyError(
#     163             f"Could not find key {k} in .{idxdim}_names or .{coldim}.columns."
#     164         )
#
# KeyError: 'Could not find key patient in .var_names or .obs.columns.'

# %%
anndata.AnnData.write(adata, filename = '/Users/gagled01/morganLab/Waldenstroms/singlecell/WM_PrelimRNA_CellTypistAnnotated.h5ad')

# %%
predictions.to_table(folder = '/Users/gagled01/morganLab/Waldenstroms/singlecell/', prefix = 'WM_Prelim_CellTypistAnnotations')
